# %% [markdown]
# ### Generador de colsulta
#
# Ver todos los campos y todos los registros de una tabla:
# - SELECT * FROM tabla	*(nombre de la tabla a consultar)*
#
# Ver uno o varios campos y todos los registros de una tabla:
# - SELECT campo1, campo2 FROM tabla;
#
# Agregarle un alias a los campos de nuestra consulta
# - SELECT campo1 as aliasCampo1, campo2 as aliasCampo2 from tabla;
#
# Filtrar la consulta por los valores de uno o varios campos
# - SELECT * FROM tabla WHERE campo1='valor1' and campo2>=9;
#
# Ordenar los registros de nuestra tabla de forma ascendente y descendente
# - SELECT * from tabla order by nota desc;
#
# Ordenar los valores minimos y maximos de un campo de una tabla:
# - SELECT min(campo) as aliasMin, max(campo) as aliasMax from tabla;
# Ejemplo:
# - SELECT 'alumnos'.'nombre','alumnos'.'nota'
# 	FROM 'alumnos'
# 	ORDER BY nota asc;
#
# Limita la cantidad de registros a mostrar:
# - SELECT * FROM tabla limit 3,2;
#
# Buscar datos que contenga una letra en específico:
# - SELECT 'alumnos'.'nombre', 'alumno'.'fecha_ingreso'
# 	FROM 'alumnos'
# 	WHERE 'alumnos'.'nombre' *LIKE %J%* AND 'alumnos'.'notas' >= '0';

# %% [markdown]
# ### Consultas con INNER JOIN, LEFT JOIN y RIGHT JOIN en MySQL
# -  INNER JOIN en SQL sirve para COMBINAR filas de dos o mas tablas basándose en un campo comnún entre ellas, devolviendo por tanto datos de diferentes tablas. Un JOIN se produce cuando dos o mas tablas se juntan en una sentencia SQL
#
# - LEFT JOIN  COMBINA LOS VALORES de la primera tabla con los valores de la segunda tabla. Siempre devolverá las filas de la *primera* tabla, incluso aunque no cumplan la condición
#
# - RIGHT JOIN  COMBINA LOS VALORES de la primera tabla con los valores de la segunda tabla. Siempre devolverá las filas de la *segunda* tabla, incluso aunque no cumplan la condición
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# SINTAXIS INNER JOIN en MySQL
#
# - SELECT tabla1.campo1, tabla1.campo2, tabla2.campo1, tabla2.campo2
# 	FROM tabla1
# 	INNER JOIN tabla2
# 	ON tabla1.idSalon = tabla2.id;
#
# Ejemplo
# - SELECT 'alumnos'.*,'salones'.*
# FROM 'alumnos'
# INNER JOIN 'salones' ON 'alumnos'.'idSalon' = 'salones'.'id';

# %% [markdown]
# LEFT JOIN
# - SELECT tabla1.campo1, tabla1.campo2, tabla2.campo1, tabla2.campo2
# 	FROM tabla1
# 	LEFT JOIN tabla2
# 	ON tabla1.idSalon = tabla2.id;

# %% [markdown]
# RIGT JOIN
#
# - SELECT tabla1.campo1, tabla1.campo2, tabla2.campo1, tabla2.campo2
# 	FROM tabla1
# 	RIGHT JOIN tabla2
# 	ON tabla1.idSalon = tabla2.id;
